# %%
from fuzzywuzzy import process
from fuzzywuzzy import fuzz
import collections
import pandas as pd

# %% [markdown]
# Below code fetches the data from the MIT dataset

# %%
house=pd.read_csv("https://dataverse.harvard.edu/api/access/datafile/:persistentId?persistentId=doi:10.7910/DVN/IG0UN2/8KAB8V", delimiter='\t')

# %% [markdown]
# Below code fetches the data from FEC site

# %%
house_candidate=pd.read_csv("https://cg-519a459a-0ea3-42c2-b7bc-fa1143481f74.s3.us-gov-west-1.amazonaws.com/8bef4b8897fa19c5b0152937d609a4aa1a2d84aea1dd23de15be3160.csv?response-content-disposition=filename%3Dcandidates-2019-07-11T09%3A41%3A22.csv&AWSAccessKeyId=AKIAR7FXZINYMI3G4BRV&Signature=Sh9AF023HAUOjO8Z3zNnNfb6mL8%3D&Expires=1563457289")

# %%
house_candidate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30052 entries, 0 to 30051
# Data columns (total 22 columns):
# name                        30052 non-null object
# office                      30052 non-null object
# office_full                 30052 non-null object
# party                       29974 non-null object
# party_full                  29943 non-null object
# state                       30052 non-null object
# district                    30029 non-null float64
# district_number             30029 non-null float64
# election_districts          30052 non-null object
# election_years              30052 non-null object
# cycles                      30052 non-null object
# candidate_status            30052 non-null object
# incumbent_challenge         27282 non-null object
# incumbent_challenge_full    27282 non-null object
# load_date                   30045 non-null object
# first_file_date             22149 non-null object
# last_file_date              22149 non-null object
# last_f2_date                21332 non-null object
# candidate_id                30052 non-null object
# active_through              30052 non-null int64
# candidate_inactive          30052 non-null object
# inactive_election_years     640 non-null object
# dtypes: float64(2), int64(1), object(19)
# memory usage: 5.0+ MB

# %%
house_candidate=house_candidate.loc[:,["name","party_full","state","district","election_years","candidate_id"]]
house_candidate.head()
# Out:
#                     name        party_full state  district election_years  \
# 0     WHITTAKER, RICHARD  DEMOCRATIC PARTY    AK       0.0         {1980}
# 1  DIERLAM, JESSE HOWELL  DEMOCRATIC PARTY    AK       0.0         {1990}
# 2          SINKOLA, GARY  REPUBLICAN PARTY    AK       0.0         {1990}
# 3            YOUNG, ANNA       GREEN PARTY    AK       0.0         {2000}
# 4  GREENE, CLIFFORD MARK  DEMOCRATIC PARTY    AK       0.0    {2000,2002}
#
#   candidate_id
# 0    H0AK00014
# 1    H0AK00022
# 2    H0AK00030
# 3    H0AK00048
# 4    H0AK00055

# %%
total=house.isnull().sum().sort_values(ascending=False)
percent=(house.isnull().sum()/house.isnull().count()).sort_values(ascending=False)
pd.concat([total,percent],keys=["Total","Percent"],axis=1)
# Out:
#                 Total   Percent
# runoff           8656  0.292077
# party            3428  0.115670
# candidate        2121  0.071568
# stage              30  0.001012
# district            0  0.000000
# state               0  0.000000
# state_po            0  0.000000
# state_fips          0  0.000000
# state_cen           0  0.000000
# state_ic            0  0.000000
# office              0  0.000000
# version             0  0.000000
# unofficial          0  0.000000
# special             0  0.000000
# writein             0  0.000000
# mode                0  0.000000
# candidatevotes      0  0.000000
# totalvotes          0  0.000000
# year                0  0.000000

# %% [markdown]
# below cell shows the basic cleaning of the data before any further process

# %%
#Sets all null runoff to False
house.loc[(house['runoff'].isnull()), 'runoff']=False

#Sets all null candidates and Parties to Other
house.loc[((house['candidate'].isnull())|(house["candidate"]=="other")), 'candidate']='Other'
house.loc[(house['party'].isnull()), 'party']='Other'
house.loc[((house["candidate"]=="scattering")|(house['candidate']=="scatter")),'candidate']="Scatter"
house.loc[(house["candidate"]=="no name"),'candidate']="Unavailable"

#Sets all of the 2006 Texas stages to general
house.loc[(house['stage'].isnull()), 'stage']='gen'

# %%
house.groupby(["candidate"]).count()
# Out:
#                               year  state  state_po  state_fips  state_cen  \
# candidate
# A. 'Cecy' R. Groom               1      1         1           1          1
# A. A. Rayner                     1      1         1           1          1
# A. A. Rayner, Jr.                1      1         1           1          1
# A. Charles Laws                  2      2         2           2          2
# A. D. (Al) Shipley               1      1         1           1          1
# A. D. (Andy) Allissandratos      1      1         1           1          1
# A. Donald McEachin               2      2         2           2          2
# A. E. \\"Tracy\"\" Potts"        1      1         1           1          1
# A. G. Baddley                    1      1         1           1          1
# A. George Sweet III              1      1         1           1          1
# A. J. Sekhon                     1      1         1           1          1
# A. J. \\"Joe\"\" Canada Jr."     1      1         1           1          1
# A. J. \\"Tony\"\" Zevgolis"      1      1         1           1          1
# A. John Elliot                   1      1         1           1          1
# A. P. (Sandy) Sands              1      1         1           1          1
# A. Peter Crane                   1      1         1           1          1
# A. Petrakopoulos                 1      1         1           1          1
# A. Stephen Dirks                 1      1         1           1          1
# A. T. \\"Art\"\" Narro"          1      1         1           1          1
# A.J. Killingsworth               1      1         1           1          1
# AL Borgman                       1      1         1           1          1
# Aage Nost                        1      1         1           1          1
# Aaron C. Davis                   1      1         1           1          1
# Aaron G. Woolf                   2      2         2           2          2
# Aaron I. Cohn                    1      1         1           1          1
# Aaron J. Andrus                  1      1         1           1          1
# Aaron Justice                    1      1         1           1          1
# Aaron M. Kromash                 1      1         1           1          1
# Aaron M. Schein                  1      1         1           1          1
# Aaron Schock                     4      4         4           4          4
# ...                            ...    ...       ...         ...        ...
# \\"Bobby\"\" Jindal"             1      1         1           1          1
# \\"Buddy\"\" Roemer"             1      1         1           1          1
# \\"Charlie\"\" Melancon"         1      1         1           1          1
# \\"Dick\"\" Swett"               1      1         1           1          1
# \\"Ed\"\" Tarpley"               1      1         1           1          1
# \\"Greg\"\" Ellison"             1      1         1           1          1
# \\"Gus\"\" Rantz"                1      1         1           1          1
# \\"Jack\"\" Radosta"             1      1         1           1          1
# \\"Jamie\"\" Mayo"               1      1         1           1          1
# \\"Jeff\"\" Landry"              1      1         1           1          1
# \\"Jerry\"\" Huckaby"            2      2         2           2          2
# \\"Jerry\"\" Watts"              1      1         1           1          1
# \\"Jim?\"\" Stark"               1      1         1           1          1
# \\"Jim\"\" Francis"              1      1         1           1          1
# \\"Jim\"\" Harlan"               1      1         1           1          1
# \\"Josh\"\" Guillory"            1      1         1           1          1
# \\"Ken\"\" Blevens"              1      1         1           1          1
# \\"Mike\"\" Johnson"             2      2         2           2          2
# \\"Mike\"\" Rogers"              1      1         1           1          1
# \\"Rick\"\" John"                1      1         1           1          1
# \\"Rick\"\" Moscatello"          1      1         1           1          1
# \\"Rob\"\" Anderson"             1      1         1           1          1
# \\"Ron\"\" Ceasar"               1      1         1           1          1
# \\"Ron\"\" Richard"              1      1         1           1          1
# \\"Silky\"\" Sullivan"           1      1         1           1          1
# \\"Tom\"\" Gibbs, Jr."           1      1         1           1          1
# \\"Trey\"\" Thomas"              1      1         1           1          1
# \\"Zach\"\" Dasher"              1      1         1           1          1
# aniel John Gorham                1      1         1           1          1
# henry Yanez                      1      1         1           1          1
#
#                               state_ic  office  district  stage  runoff  \
# candidate
# A. 'Cecy' R. Groom                   1       1         1      1       1
# A. A. Rayner                         1       1         1      1       1
# A. A. Rayner, Jr.                    1       1         1      1       1
# A. Charles Laws                      2       2         2      2       2
# A. D. (Al) Shipley                   1       1         1      1       1
# A. D. (Andy) Allissandratos          1       1         1      1       1
# A. Donald McEachin                   2       2         2      2       2
# A. E. \\"Tracy\"\" Potts"            1       1         1      1       1
# A. G. Baddley                        1       1         1      1       1
# A. George Sweet III                  1       1         1      1       1
# A. J. Sekhon                         1       1         1      1       1
# A. J. \\"Joe\"\" Canada Jr."         1       1         1      1       1
# A. J. \\"Tony\"\" Zevgolis"          1       1         1      1       1
# A. John Elliot                       1       1         1      1       1
# A. P. (Sandy) Sands                  1       1         1      1       1
# A. Peter Crane                       1       1         1      1       1
# A. Petrakopoulos                     1       1         1      1       1
# A. Stephen Dirks                     1       1         1      1       1
# A. T. \\"Art\"\" Narro"              1       1         1      1       1
# A.J. Killingsworth                   1       1         1      1       1
# AL Borgman                           1       1         1      1       1
# Aage Nost                            1       1         1      1       1
# Aaron C. Davis                       1       1         1      1       1
# Aaron G. Woolf                       2       2         2      2       2
# Aaron I. Cohn                        1       1         1      1       1
# Aaron J. Andrus                      1       1         1      1       1
# Aaron Justice                        1       1         1      1       1
# Aaron M. Kromash                     1       1         1      1       1
# Aaron M. Schein                      1       1         1      1       1
# Aaron Schock                         4       4         4      4       4
# ...                                ...     ...       ...    ...     ...
# \\"Bobby\"\" Jindal"                 1       1         1      1       1
# \\"Buddy\"\" Roemer"                 1       1         1      1       1
# \\"Charlie\"\" Melancon"             1       1         1      1       1
# \\"Dick\"\" Swett"                   1       1         1      1       1
# \\"Ed\"\" Tarpley"                   1       1         1      1       1
# \\"Greg\"\" Ellison"                 1       1         1      1       1
# \\"Gus\"\" Rantz"                    1       1         1      1       1
# \\"Jack\"\" Radosta"                 1       1         1      1       1
# \\"Jamie\"\" Mayo"                   1       1         1      1       1
# \\"Jeff\"\" Landry"                  1       1         1      1       1
# \\"Jerry\"\" Huckaby"                2       2         2      2       2
# \\"Jerry\"\" Watts"                  1       1         1      1       1
# \\"Jim?\"\" Stark"                   1       1         1      1       1
# \\"Jim\"\" Francis"                  1       1         1      1       1
# \\"Jim\"\" Harlan"                   1       1         1      1       1
# \\"Josh\"\" Guillory"                1       1         1      1       1
# \\"Ken\"\" Blevens"                  1       1         1      1       1
# \\"Mike\"\" Johnson"                 2       2         2      2       2
# \\"Mike\"\" Rogers"                  1       1         1      1       1
# \\"Rick\"\" John"                    1       1         1      1       1
# \\"Rick\"\" Moscatello"              1       1         1      1       1
# \\"Rob\"\" Anderson"                 1       1         1      1       1
# \\"Ron\"\" Ceasar"                   1       1         1      1       1
# \\"Ron\"\" Richard"                  1       1         1      1       1
# \\"Silky\"\" Sullivan"               1       1         1      1       1
# \\"Tom\"\" Gibbs, Jr."               1       1         1      1       1
# \\"Trey\"\" Thomas"                  1       1         1      1       1
# \\"Zach\"\" Dasher"                  1       1         1      1       1
# aniel John Gorham                    1       1         1      1       1
# henry Yanez                          1       1         1      1       1
#
#                               special  party  writein  mode  candidatevotes  \
# candidate
# A. 'Cecy' R. Groom                  1      1        1     1               1
# A. A. Rayner                        1      1        1     1               1
# A. A. Rayner, Jr.                   1      1        1     1               1
# A. Charles Laws                     2      2        2     2               2
# A. D. (Al) Shipley                  1      1        1     1               1
# A. D. (Andy) Allissandratos         1      1        1     1               1
# A. Donald McEachin                  2      2        2     2               2
# A. E. \\"Tracy\"\" Potts"           1      1        1     1               1
# A. G. Baddley                       1      1        1     1               1
# A. George Sweet III                 1      1        1     1               1
# A. J. Sekhon                        1      1        1     1               1
# A. J. \\"Joe\"\" Canada Jr."        1      1        1     1               1
# A. J. \\"Tony\"\" Zevgolis"         1      1        1     1               1
# A. John Elliot                      1      1        1     1               1
# A. P. (Sandy) Sands                 1      1        1     1               1
# A. Peter Crane                      1      1        1     1               1
# A. Petrakopoulos                    1      1        1     1               1
# A. Stephen Dirks                    1      1        1     1               1
# A. T. \\"Art\"\" Narro"             1      1        1     1               1
# A.J. Killingsworth                  1      1        1     1               1
# AL Borgman                          1      1        1     1               1
# Aage Nost                           1      1        1     1               1
# Aaron C. Davis                      1      1        1     1               1
# Aaron G. Woolf                      2      2        2     2               2
# Aaron I. Cohn                       1      1        1     1               1
# Aaron J. Andrus                     1      1        1     1               1
# Aaron Justice                       1      1        1     1               1
# Aaron M. Kromash                    1      1        1     1               1
# Aaron M. Schein                     1      1        1     1               1
# Aaron Schock                        4      4        4     4               4
# ...                               ...    ...      ...   ...             ...
# \\"Bobby\"\" Jindal"                1      1        1     1               1
# \\"Buddy\"\" Roemer"                1      1        1     1               1
# \\"Charlie\"\" Melancon"            1      1        1     1               1
# \\"Dick\"\" Swett"                  1      1        1     1               1
# \\"Ed\"\" Tarpley"                  1      1        1     1               1
# \\"Greg\"\" Ellison"                1      1        1     1               1
# \\"Gus\"\" Rantz"                   1      1        1     1               1
# \\"Jack\"\" Radosta"                1      1        1     1               1
# \\"Jamie\"\" Mayo"                  1      1        1     1               1
# \\"Jeff\"\" Landry"                 1      1        1     1               1
# \\"Jerry\"\" Huckaby"               2      2        2     2               2
# \\"Jerry\"\" Watts"                 1      1        1     1               1
# \\"Jim?\"\" Stark"                  1      1        1     1               1
# \\"Jim\"\" Francis"                 1      1        1     1               1
# \\"Jim\"\" Harlan"                  1      1        1     1               1
# \\"Josh\"\" Guillory"               1      1        1     1               1
# \\"Ken\"\" Blevens"                 1      1        1     1               1
# \\"Mike\"\" Johnson"                2      2        2     2               2
# \\"Mike\"\" Rogers"                 1      1        1     1               1
# \\"Rick\"\" John"                   1      1        1     1               1
# \\"Rick\"\" Moscatello"             1      1        1     1               1
# \\"Rob\"\" Anderson"                1      1        1     1               1
# \\"Ron\"\" Ceasar"                  1      1        1     1               1
# \\"Ron\"\" Richard"                 1      1        1     1               1
# \\"Silky\"\" Sullivan"              1      1        1     1               1
# \\"Tom\"\" Gibbs, Jr."              1      1        1     1               1
# \\"Trey\"\" Thomas"                 1      1        1     1               1
# \\"Zach\"\" Dasher"                 1      1        1     1               1
# aniel John Gorham                   1      1        1     1               1
# henry Yanez                         1      1        1     1               1
#
#                               totalvotes  unofficial  version
# candidate
# A. 'Cecy' R. Groom                     1           1        1
# A. A. Rayner                           1           1        1
# A. A. Rayner, Jr.                      1           1        1
# A. Charles Laws                        2           2        2
# A. D. (Al) Shipley                     1           1        1
# A. D. (Andy) Allissandratos            1           1        1
# A. Donald McEachin                     2           2        2
# A. E. \\"Tracy\"\" Potts"              1           1        1
# A. G. Baddley                          1           1        1
# A. George Sweet III                    1           1        1
# A. J. Sekhon                           1           1        1
# A. J. \\"Joe\"\" Canada Jr."           1           1        1
# A. J. \\"Tony\"\" Zevgolis"            1           1        1
# A. John Elliot                         1           1        1
# A. P. (Sandy) Sands                    1           1        1
# A. Peter Crane                         1           1        1
# A. Petrakopoulos                       1           1        1
# A. Stephen Dirks                       1           1        1
# A. T. \\"Art\"\" Narro"                1           1        1
# A.J. Killingsworth                     1           1        1
# AL Borgman                             1           1        1
# Aage Nost                              1           1        1
# Aaron C. Davis                         1           1        1
# Aaron G. Woolf                         2           2        2
# Aaron I. Cohn                          1           1        1
# Aaron J. Andrus                        1           1        1
# Aaron Justice                          1           1        1
# Aaron M. Kromash                       1           1        1
# Aaron M. Schein                        1           1        1
# Aaron Schock                           4           4        4
# ...                                  ...         ...      ...
# \\"Bobby\"\" Jindal"                   1           1        1
# \\"Buddy\"\" Roemer"                   1           1        1
# \\"Charlie\"\" Melancon"               1           1        1
# \\"Dick\"\" Swett"                     1           1        1
# \\"Ed\"\" Tarpley"                     1           1        1
# \\"Greg\"\" Ellison"                   1           1        1
# \\"Gus\"\" Rantz"                      1           1        1
# \\"Jack\"\" Radosta"                   1           1        1
# \\"Jamie\"\" Mayo"                     1           1        1
# \\"Jeff\"\" Landry"                    1           1        1
# \\"Jerry\"\" Huckaby"                  2           2        2
# \\"Jerry\"\" Watts"                    1           1        1
# \\"Jim?\"\" Stark"                     1           1        1
# \\"Jim\"\" Francis"                    1           1        1
# \\"Jim\"\" Harlan"                     1           1        1
# \\"Josh\"\" Guillory"                  1           1        1
# \\"Ken\"\" Blevens"                    1           1        1
# \\"Mike\"\" Johnson"                   2           2        2
# \\"Mike\"\" Rogers"                    1           1        1
# \\"Rick\"\" John"                      1           1        1
# \\"Rick\"\" Moscatello"                1           1        1
# \\"Rob\"\" Anderson"                   1           1        1
# \\"Ron\"\" Ceasar"                     1           1        1
# \\"Ron\"\" Richard"                    1           1        1
# \\"Silky\"\" Sullivan"                 1           1        1
# \\"Tom\"\" Gibbs, Jr."                 1           1        1
# \\"Trey\"\" Thomas"                    1           1        1
# \\"Zach\"\" Dasher"                    1           1        1
# aniel John Gorham                      1           1        1
# henry Yanez                            1           1        1
#
# [15040 rows x 18 columns]

# %% [markdown]
# Below cell is use to expand the year data from FEC which is in {1988,1990} to seprate two columns one for 1988 amd other for 1990.

# %%
def eyear(nd):
    l=[]
    for index,row in nd.iterrows():
        i=row.values
        t=i[4]
        j=t.strip('{').strip('}').split(',')
        for x in j:
            l.append([i[0],i[1],i[2],i[3],int(x),i[5]])
    return l

# %%
house_candidate1=pd.DataFrame(eyear(house_candidate))
house_candidate1.columns=["name","party","state","district","year","candidate_id"]
house_candidate1=house_candidate1[(house_candidate1["year"]>=1976)&(house_candidate1["year"]<=2018)]

# %% [markdown]
# Below function used to modify the candidate name in FEc data to be in the same format as the MIT data

# %%
def modify(x):
    sl=x.replace('"','').split(',')
    sl.reverse()
    s=""
    for i in sl:
        s=s+i+" "
    return s.strip()

# %%
print(modify("DIERLAM, JESSE HOWELL"))
# Out:
# JESSE HOWELL DIERLAM

# %% [markdown]
# Below code shows the subsequent string matching such as ""abc def" to bc abc def dsf" and also ehlping to cause less restrain on the fuzzywuzzy logic.

# %%
def subsequence(s1,s2,m,n):
    b=0
    a=0
    while b<m and a<n:
        if s1[b]==s2[a]:
            b+=1
        a+=1
    return b==m

# %%
x=[modify(i).lower() for i in house_candidate1["name"].unique()]
y=[i.replace('\\','').replace('"','').lower() for i in house["candidate"].unique()]
l=collections.defaultdict(list)
for i in y:   
#     if i not in x:
#         l[i].append("")
#         continue
    f=0
    for j in x:
        # if i is equal to j we append it to the list of the hashmap for the name in the mit data
        if i==j:
            l[i].append(j)
            break
        # if they are similar we merge all the possible outcomes and use fuzz ratio technique to find the best match out of it
        elif subsequence(i,j,len(i),len(j)) or subsequence(j,i,len(j),len(i)):
            l[i].append(j)
        else:
            f+=1
    # if it found nowhere in the fec data we add ""(blank string) to the dictionary
    if f>=len(x):
        l[i].append("")
#     t=process.extractOne(i,x)
#     if t[1]<90:
#         l[i]=""
#     else:
#         l[i]=t[0]
#print(l)
# Out:
# defaultdict(<class 'list'>, {'bill davenport': [''], 'jack edwards': [''], 'other': [''], 'j. carole keahey': [''], 'william l. bill dickinson': [''], 'bill nichols': ['bill nichols'], 'ogburn gardner': [''], 'tom bevill': ['tom bevill'], 'leonard wilson': [''], 'ronnie g. flippo': [''], 'billy e. dorsey': [''], 'mel bailey': [''], 'john h. buchanan, jr.': [''], 'walter flowers': [''], 'don young': [''], 'eben hopson': ['eben hopson'], 'harry braun': [''], 'john j. rhodes': [''], 'summer duncan dodge': [''], 'patricia m. fullinwider': [''], 'laird guttersen': [''], 'michael emerling': [''], 'morris k. udall': [''], 'bill mccune': [''], 'bob stump': ['bob stump'], 'fred koory, jr.': [''], 'pat harper': [''], 'eldon rudd': ['eldon rudd'], 'tony mason': [''], 'harlan bo holleman': [''], 'bill alexander': [''], 'jim guy tucker': [''], 'james j. kelly': [''], 'john paul hammerschmidt': ['john paul hammerschmidt'], 'ray thornton': ['ray thornton'], 'james e. taylor': [''], 'harold t. (bizz) johnson': [''], 'robert b. allred': [''], 'oscar klee': [''], 'don h. clausen': [''], 'george r. marsh, jr.': [''], 'john e. moss': ['john e. moss'], 'albert dehr': [''], 'robert l. leggett': ['robert l. leggett'], 'branwell fanning': [''], 'john l. burton': [''], 'raymond o. heaps': [''], 'tom spinosa': ['tom spinosa'], 'emily siegel': [''], 'phillip burton': ['phillip burton'], 'robert l. vickers': [''], 'george miller': ['george miller'], 'melvin e. stanley': ['melvin e. stanley'], 'robert j. evans': [''], 'philip stiles breck, jr.': [''], 'ronald v. dellums': [''], 'fortney h. (pete) stark': [''], 'james k. mills': [''], 'albert l. sargis': [''], 'herb smith': [''], 'edmon v. kaiser': [''], 'don edwards': ['edwin washington edwards', 'donna fern edwards', 'donald edward stribling', 'don edwards'], 'leo j. ryan': ['leo j. ryan'], 'nicholas w. kudrovzeff': ['nicholas w. kudrovzeff'], 'bob jones': [''], 'david harris': [''], 'joseph david cooney': [''], 'paul n. pete mccloskey, jr.': [''], 'ernest l. konnyu': [''], 'william p. herrell': [''], 'norman y. mineta': [''], 'john j. mcfall': ['john j. mcfall'], 'roger a. blain': [''], 'b. f. sisk': ['b. f. sisk'], 'carol harner': ['carol harner'], 'burt talcott': [''], 'leon e. panetta': [''], 'john krebs': ['john krebs'], 'henry j. andreas': [''], 'dean close': [''], 'william m. ketchum': [''], 'dan sisson': [''], 'robert j. lagomarsino': [''], 'barry goldwater, jr.': [''], 'patti lear corman': [''], 'james c. corman': ['james c. corman'], 'bill hill': [''], 'erwin ed hogan': [''], 'carlos j. moorhead': [''], 'robert l. salley': [''], 'thomas f. bartman': [''], 'anthony c. beilenson': [''], 'david irving simmons': [''], 'heny a. waxman': [''], 'jim madrid': [''], 'marilyn seals': [''], 'edward r. roybal': [''], 'john h. rousselot': [''], 'bruce latta': [''], 'gary familian': [''], 'robert k. dornan': [''], 'edward s. skinner': [''], 'yvonne brathwaite burke': ['yvonne brathwaite burke'], 'sheila leburg': [''], 'michael d. germonprez': [''], 'augustus f. gus hawkins': [''], 'harry couch': [''], 'georg e. danielson': [''], 'charles ii. wilson': [''], 'clifford o. young': ['clifford o. young'], 'glenn m. anderson': [''], 'del clawson': ['dan', 'del clawson'], 'ted snyder': [''], 'daniel e. lungren': ['dan', 'daniel e. lungren'], 'mark w. hannaford': [''], 'jim lloyd': [''], 'louis brutocao': [''], 'george e. brown, jr.': [''], 'william pasley': [''], 'grant carner': [''], 'bernard wahl': ['bernard wahl'], 'douglas c. nilson, jr.': [''], 'shirley n. pettis': ['shirley n. pettis'], 'james (jim) combs': [''], 'jerry patterson': [''], 'william e. bill farris': [''], 'charles e. wiggins': ['charles e. wiggins'], 'vivian hall': [''], 'robert e. badham': [''], 'bob c. wilson': [''], 'king golden, jr.': [''], 'wes marden': [''], 'lionel van deerlin': [''], 'clair w. burgener': [''], 'pat kelly': [''], 'lann meyers': [''], 'don friedman': ['dan', 'don friedman'], 'patricia schroeder': ['patricia schroeder'], 'pr ...

# %% [markdown]
# Below code uses the dictonary generarted in the above code and find a better match using the fuzzy wuzzy method

# %%
print(len(x))
print(len(y))
compare=[]
for key,value in l.items():
# if the lenth of the dictonary is 1 and contains a null value we use fuzzy wuzzy logic and replace it with the match having atleast 90% similarity
    if len(value)==1:    
        if value[0]=="":
            t=process.extractOne(key,x)
            if t[1]>90:
                compare.append([key,t[0]])
            else:
                compare.append([key,""])
        else:
            compare.append([key,value[0]])
    else:
        s=""
        m=-1
# if there is already a potential match we just loook for the best from the posible match found using the previous logic
        for i in value:
            if fuzz.ratio(key,i)>m:
                m=fuzz.ratio(key,i)
                s=i
        compare.append([key,s])
print(compare)
# Out:
# 28889
# 15040
